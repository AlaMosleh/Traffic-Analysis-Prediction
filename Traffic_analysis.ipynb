# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/traffic.csv")
df
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2976 entries, 0 to 2975
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Time               2976 non-null   object
#  1   Date               2976 non-null   int64
#  2   Day of the week    2976 non-null   object
#  3   CarCount           2976 non-null   int64
#  4   BikeCount          2976 non-null   int64
#  5   BusCount           2976 non-null   int64
#  6   TruckCount         2976 non-null   int64
#  7   Total              2976 non-null   int64
#  8   Traffic Situation  2976 non-null   object
# dtypes: int64(6), object(3)
# memory usage: 209.4+ KB

# %%
df.isnull().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 1) Vehicle Distribution Analysis:

# %%
#using Boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(data=df[["CarCount", "BikeCount", "BusCount", "TruckCount"]])
plt.title("Boxplot of Vehicle Count Distribution")
plt.show()

# %%
# Using Histogram
plt.figure(figsize=(8, 5))
plt.hist(df[["CarCount", "BikeCount", "BusCount", "TruckCount"]], bins=10)
plt.title("Histogram of Vehicle Count Distribution")
plt.xlabel("Vehicle Count")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(9,6))

plt.subplot(2, 2, 1)
plt.hist(df['CarCount'], bins=20, color='blue', edgecolor='black')
plt.title('Car Count Distribution')
plt.xlabel('Car Count')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
plt.hist(df['BikeCount'],bins=20,edgecolor='black')
plt.title('Bike Count Distribution')
plt.xlabel('Bike Count')
plt.ylabel('Frequency')

plt.subplot(2, 2, 3)
plt.hist(df['BusCount'], bins=20, color='red', edgecolor='black')
plt.title('Bus Count Distribution')
plt.xlabel('Bus Count')
plt.ylabel('Frequency')

plt.subplot(2, 2, 4)
plt.hist(df['TruckCount'], bins=20,color='green', edgecolor='black')
plt.title('Truck Count Distribution')
plt.xlabel('Truck Count')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# 2) Traffic Situation Distribution:

# %%
df['Traffic Situation'].value_counts()
# Out:
# Traffic Situation
# normal    1669
# heavy      682
# high       321
# low        304
# Name: count, dtype: int64

# %%
#using pie chart
plt.figure(figsize=(9, 5))
traffic_situation_counts = df["Traffic Situation"].value_counts()
label=traffic_situation_counts.index
plt.pie(traffic_situation_counts, autopct='%1.1f%%')
plt.title("Traffic Situation Distribution")
plt.legend(label, title="Traffic Situation")
plt.show()

# %% [markdown]
# 3) Variation by Day of the Week:

# %%
# there is already a day of the week column so i used it and when i extract the day from the Time column it only shows Sunday
# Plotting the vehicle counts by day of the week using bar plots
#df['Day'] = pd.to_datetime(df['Time']).dt.day_name()
vehicles=['CarCount','BikeCount','BusCount','TruckCount']
for vehicle in vehicles:

 plt.figure(figsize=(7, 5))
 sns.barplot(x='Day of the week', y=vehicle, data=df)
 plt.title(vehicle+' by Day of the Week')
 plt.xlabel('Day of the Week')
 plt.ylabel(vehicle)
 plt.show()

# %% [markdown]
# 4) Car Count vs. Traffic Situation:

# %%
# Create scatter plot
plt.figure(figsize=(9, 6))
sns.scatterplot(x='Traffic Situation', y='CarCount', data=df, hue='Traffic Situation', palette='viridis')
plt.title('Car Count vs. Traffic Situation (Scatter Plot)')
plt.xlabel('Traffic Situation')
plt.ylabel('Car Count')
plt.show()

# Create boxplot
plt.figure(figsize=(9, 6))
sns.boxplot(x='Traffic Situation', y='CarCount', data=df, palette='viridis')
plt.title('Car Count vs. Traffic Situation (Box Plot)')
plt.xlabel('Traffic Situation')
plt.ylabel('Car Count')
plt.show()

# %% [markdown]
# 5) Bike Count vs. Traffic Situation:

# %%
#using scatter plot
plt.figure(figsize=(9, 6))
sns.scatterplot(x='Traffic Situation', y='BikeCount', data=df, hue='Traffic Situation', palette='viridis')
plt.title('Bike Count vs. Traffic Situation')
plt.xlabel('Traffic Situation')
plt.ylabel('Bike Count')
plt.show()

# %% [markdown]
# 6) Bus Count vs. Traffic Situation:

# %%
#using scatter plot
plt.figure(figsize=(9, 6))
sns.scatterplot(x='Traffic Situation', y='BusCount', data=df, hue='Traffic Situation', palette='viridis')
plt.title('Bus Count vs. Traffic Situation')
plt.xlabel('Traffic Situation')
plt.ylabel('Bus Count')
plt.show()

# %% [markdown]
# 7) Truck Count vs. Traffic Situation:

# %%
#using scatter plot
plt.figure(figsize=(9, 6))
sns.scatterplot(x='Traffic Situation', y='TruckCount', data=df, hue='Traffic Situation', palette='viridis')
plt.title('Truck Count vs. Traffic Situation')
plt.xlabel('Traffic Situation')
plt.ylabel('Truck Count')
plt.show()

# %% [markdown]
# 8) Total Vehicle and Count Traffic Situation:

# %%
# Group the data by Traffic Situation and calculate the total vehicle count for each
total_by_traffic_situation = df.groupby('Traffic Situation')['Total'].sum().reset_index()

plt.figure(figsize=(9, 6))
sns.barplot(x='Traffic Situation', y='Total', data=total_by_traffic_situation, palette='viridis')
plt.title('Total Vehicle Count by Traffic Situation')
plt.xlabel('Traffic Situation')
plt.ylabel('Total Vehicle Count')
plt.show()

# %%
total_by_traffic_situation
# Out:
#   Traffic Situation   Total
# 0             heavy  135622
# 1              high   45721
# 2               low   19758
# 3            normal  138813

# %% [markdown]
# 9) Busiest Hours of the Day:

# %%
from dateutil import parser
# Extract the hour from the Time column using dateutil.parser
df['Hour'] = df['Time'].apply(lambda x: parser.parse(x).hour)

# Group by the hour and calculate the total vehicle count for each hour
total_by_hour = df.groupby('Hour')['Total'].sum().reset_index()

# Plotting the total vehicle count by hour using a bar chart
plt.figure(figsize=(9, 6))
sns.barplot(x='Hour', y='Total', data=total_by_hour, palette='viridis')
plt.title('Total Vehicle Count by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Vehicle Count')
plt.show()

# Plotting the total vehicle count by hour and day using a heatmap
heatmap_data = df.pivot_table(index='Hour', columns='Day of the week', values='Total', aggfunc='sum')
plt.figure(figsize=(9, 6))
sns.heatmap(heatmap_data, cmap='viridis', annot=True, fmt='g')
plt.title('Heatmap of Total Vehicle Count by Hour and Day')
plt.xlabel('Day of the Week')
plt.ylabel('Hour of the Day')
plt.show()

# %% [markdown]
# How does traffic situation distribution vary by day of the week

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(x='Day of the week', y='Traffic Situation', data=df, palette='viridis')
plt.title('Traffic Situation by day of the week')
plt.ylabel('Traffic Situation')
plt.xlabel('Day of the week')
plt.show()

# %% [markdown]
# # Insights from the chart
#
# 1. Friday: This day stands out with a higher median traffic situation compared to other days, indicating more traffic. Additionally, the spread of data is wider, suggesting more variability in traffic conditions on Fridays. This could be due to increased activity as the weekend approaches.
#
# 2. other days: Traffic on these days is relatively consistent, with medians around the "normal" level. The interquartile range (IQR) and whiskers suggest that the spread of traffic data is similar, indicating stable traffic patterns on these weekdays.

# %% [markdown]
# What are the correlations between different vehicle types

# %%
plt.figure(figsize=(9, 6))
sns.heatmap(df[['BikeCount','BusCount','TruckCount','CarCount','Total']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation matrix of vehicle counts')
plt.show()

# %% [markdown]
# ## Insights from the chart
# * The correlation between Truck count and the othe column is an inverse relationship. When the number of trucks increases, the number of bikes tends to decrease and so on for the others too.
# * Most vehicle types (BikeCount, BusCount, CarCount) show positive correlations with the total vehicle count, which is expected as each type contributes to the overall count.

# %% [markdown]
# How does the distribution of traffic situations differ by hour

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(x='Hour', y='Traffic Situation', data=df, palette='viridis')
plt.title('Traffic Situation by Hour')
plt.ylabel('Traffic Situation')
plt.xlabel('Hour')
plt.show()

# %% [markdown]
# # Insights from the chart
#
# 1. Low Traffic:
#    - Occurs across a wide range of hours, from 5 till 20.
#    - The median suggests low traffic is most common in the earlier hours.
#
# 2. Normal Traffic:
#    - Spread across a significant portion of the day.
#    - The median is around 12 (mid-day), indicating normal traffic is most common during daytime.
#
# 3. Heavy Traffic:
#    - More concentrated from 7 till 17.
#    - The interquartile range suggests that heavy traffic is most frequent in the morning and afternoon.
#
# 4. High Traffic:
#    - Mostly occurs from 10 till 20.
#    - high traffic is rare in the early morning hours.
#    - The median confirms that the most crowded period is later in the day.

# %% [markdown]
# What is the distribution of total vehicle counts for each day of the week

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(x='Day of the week', y='Total', data=df, palette='viridis')
plt.title('Total Vehicle Count by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# # Insights from the chart
#
# 1. The median vehicle count varies by day of the week, with most days showing medians around 100 vehicles. This suggests a consistent level of traffic on these days.
# 2. Friday stands out with a slightly lower median vehicle count compared to other days, along with a wider range of counts. This could indicate more variability in traffic patterns on Fridays.

# %% [markdown]
# How does the variance in vehicle counts compare across vehicle types

# %%
vehicle_variances = df[['CarCount', 'BikeCount', 'BusCount', 'TruckCount']].var()

plt.figure(figsize=(9, 6))
vehicle_variances.plot(kind='bar',color='navy')
plt.title('Variance in Vehicle Counts')
plt.xlabel('Vehicle Type')
plt.ylabel('Variance')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Insights from the chart:
#
# 1. The CarCount variance is significantly higher than all other vehicle types.This suggests that the number of cars fluctuates widely over time.
#
# 2. BikeCount, BusCount, and TruckCount show much lower variance compared to cars.This indicates that their numbers remain relatively stable over time.

# %% [markdown]
# How does the average vehicle count for each type change over time

# %%
import plotly.express as px
# plotly creates an interactive chart
# Reshape data: Convert wide format into long format making it easier to plot different vehicle types in one graph.

df_melted = df.melt(id_vars=['Time'], value_vars=['CarCount', 'BikeCount', 'BusCount', 'TruckCount'],
                     var_name='Vehicle Type', value_name='Count')

# Compute the average count per time for each vehicle type
df_grouped = df_melted.groupby(['Time', 'Vehicle Type'])['Count'].mean().reset_index()

# Create an interactive line chart

fig = px.line(df_grouped, x='Time', y='Count', color='Vehicle Type',
              title='Average Vehicle Counts Over Time',
              labels={'Count': 'Average Count', 'Time': 'Time'},
              markers=True)
fig.update_layout(width=1000,height=600)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #Insights from the chart
#
# 1. Car Count (green line)
#
#   The car count fluctuates significantly over time.
#   There is a noticeable increase in the count after a specific time (around 4:00 AM), indicating a surge in vehicle movement.
#   After peaking, there is a slight decline towards the end.
#
# 2. Bike Count (Blue Line)
#
#   The bike count remains relatively low throughout the timeline.
#   there is a small fluctuations but stays within a narrow range.
#
# 3. Bus Count (Red Line)
#
#   The bus count follows a pattern of low and moderate peaks, possibly representing scheduled bus routes.
#
# 4. Truck Count (Purple Line)
#
#   The truck count remains relatively stable but exhibits small fluctuations.
#   At certain points, there is a slight drop in truck numbers, which could indicate specific time restrictions for trucks.
